# %%
file_path = "C:\\Users\\Pujan thapa magar\\OneDrive\\Documents\\"
file_name = "default"
file_type = ".txt"
f_path = file_path+file_name+file_type
file = open(f_path)
for i in file:
    print(i)
# Out:
# <html>
#
# <head>
#
# <title> Javascript </title>
#
# </head>
#
# <body>
#
# <script>
#
# var a=5,b=10;
#
# document.write("sum=",a+b+"<br>)
#
# document.write("Difference=",a-b+"<br>)
#
# var a=parseInt(prompt("Enter 1st no=")), x=prompt("Enter string")
#
# document.write("String=",x)
#
# </script>
#
# </body>
#
# </html>

# %%
s1 = "abc"
s2 = "ABC"
for i,j in zip(s1,s2):
    print(i,j)
# Out:
# a A
# b B
# c C
